# %% [markdown]
# ## Topic Models for Aspect Extraction: LDA Model and NMF Model
# ### 1. Data Loading

# %%
import pandas as pd
# df = pd.read_csv("./data/yelp_data.csv")

ca_file_path = '../../../data/ca_restaurants.csv'
ca_df = pd.read_csv(ca_file_path)
ca_df
# Out:
#         Unnamed: 0               review_id                 user_id  \
# 0             1375  pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw
# 1             1376  _Ub20uO1MKy4XOVPOdzpqw  lUYboGI6aFbZ0dX27pijpA
# 2             1377  -DjIfoNFAiT5J4kF9hXocQ  SrfDRvGKI8FQq9LCr0dQuQ
# 3             1378  URe-2Zlv7RoY4Ycr9JYVWw  SfMf7DEX7xT82OCcbZFsgQ
# 4             1379  tHP5ihPd_W9OzfkKEWdIwA  aH3AH7V9g60w4pt3LpJ1_Q
# ...            ...                     ...                     ...
# 247608     6990221  cKuP5pnvbvpn4UbaccVcdg  OVYb1El25BgVhgbXb4e-KA
# 247609     6990222  dZC87sZ1f2ntOf876_DDLg  9w5PoliouEyNikdy6DizqQ
# 247610     6990223  NCafkcXIvK7E965my4RpQg  GmuHOkMR80oW3sAuF-UsAw
# 247611     6990224  VxsNftGxRUDZcLD0Ns1wKg  VRXPOvlSydho0tYmSseKnQ
# 247612     6990225  beFM3Lm5Pj6Spr8x6RV9Cg  uoYuvbxTCB0eu1UF4sUTcA
#
#                    business_id  stars_x  useful  funny  cool  \
# 0       gebiRewfieSdtt17PTW6Zg        3       0      0     0
# 1       gebiRewfieSdtt17PTW6Zg        1       0      2     0
# 2       gebiRewfieSdtt17PTW6Zg        3       9      4     6
# 3       gebiRewfieSdtt17PTW6Zg        5       1      0     1
# 4       gebiRewfieSdtt17PTW6Zg        4       0      0     0
# ...                        ...      ...     ...    ...   ...
# 247608  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     0
# 247609  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     0
# 247610  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     0
# 247611  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     0
# 247612  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     1
#
#                                                      text  \
# 0       Had a party of 6 here for hibachi. Our waitres...
# 1       Sat down over a half hour, only miso and drink...
# 2       Not bad. Sushi roll was good but options were ...
# 3       I'm very picky when it comes to Sushi. Quality...
# 4       Even though the sushi masters are not actually...
# ...                                                   ...
# 247608  Great experience with great people who are rea...
# 247609  I spent the week in Santa Barbara and had the ...
# 247610  Last summer, I had the pleasure of experiencin...
# 247611  Joseph and Teresa are super hosts.  You will f...
# 247612  I discovered Santa Barbara Tours and Experienc...
#
#                                  date  ... postal_code   latitude   longitude  \
# 0       2016-07-25 07:31:06.000000000  ...       93101  34.416984 -119.695556
# 1       2017-06-28 01:04:59.000000000  ...       93101  34.416984 -119.695556
# 2       2017-01-14 23:31:35.000000000  ...       93101  34.416984 -119.695556
# 3       2016-07-14 23:09:38.000000000  ...       93101  34.416984 -119.695556
# 4       2014-11-30 07:35:54.000000000  ...       93101  34.416984 -119.695556
# ...                               ...  ...         ...        ...         ...
# 247608  2021-06-22 21:41:07.000000000  ...       93101  34.429487 -119.706043
# 247609  2021-06-28 23:53:44.000000000  ...       93101  34.429487 -119.706043
# 247610  2021-07-06 19:15:56.000000000  ...       93101  34.429487 -119.706043
# 247611  2021-07-01 03:44:10.000000000  ...       93101  34.429487 -119.706043
# 247612  2021-07-27 20:41:20.000000000  ...       93101  34.429487 -119.706043
#
#        stars_y  review_count  is_open  \
# 0          3.5           488        1
# 1          3.5           488        1
# 2          3.5           488        1
# 3          3.5           488        1
# 4          3.5           488        1
# ...        ...           ...      ...
# 247608     5.0             5        1
# 247609     5.0             5        1
# 247610     5.0             5        1
# 247611     5.0             5        1
# 247612     5.0             5        1
#
#                                                attributes  \
# 0       {'Corkage': 'False', 'RestaurantsTakeOut': 'Tr...
# 1       {'Corkage': 'False', 'RestaurantsTakeOut': 'Tr...
# 2       {'Corkage': 'False', 'RestaurantsTakeOut': 'Tr...
# 3       {'Corkage': 'False', 'RestaurantsTakeOut': 'Tr...
# 4       {'Corkage': 'False', 'RestaurantsTakeOut': 'Tr...
# ...                                                   ...
# 247608                                                NaN
# 247609                                                NaN
# 247610                                                NaN
# 247611                                                NaN
# 247612                                                NaN
#
#                                                categories  \
# 0          Steakhouses, Sushi Bars, Restaurants, Japanese
# 1          Steakhouses, Sushi Bars, Restaurants, Japanese
# 2          Steakhouses, Sushi Bars, Restaurants, Japanese
# 3          Steakhouses, Sushi Bars, Restaurants, Japanese
# 4          Steakhouses, Sushi Bars, Restaurants, Japanese
# ...                                                   ...
# 247608  Tours, Walking Tours, Hotels & Travel, Archite...
# 247609  Tours, Walking Tours, Hotels & Travel, Archite...
# 247610  Tours, Walking Tours, Hotels & Travel, Archite...
# 247611  Tours, Walking Tours, Hotels & Travel, Archite...
# 247612  Tours, Walking Tours, Hotels & Travel, Archite...
#
#                                                     hours  is_restaurant
# 0                                   {'Monday': '0:0-0:0'}              Y
# 1                                   {'Monday': '0:0-0:0'}              Y
# 2                                   {'Monday': '0:0-0:0'}              Y
# 3                                   {'Monday': '0:0-0:0'}              Y
# 4                                   {'Monday': '0:0-0:0'}              Y
# ...                                                   ...            ...
# 247608  {'Friday': '20:0-22:0', 'Saturday': '10:0-23:3...              Y
# 247609  {'Friday': '20:0-22:0', 'Saturday': '10:0-23:3...              Y
# 247610  {'Friday': '20:0-22:0', 'Saturday': '10:0-23:3...              Y
# 247611  {'Friday': '20:0-22:0', 'Saturday': '10:0-23:3...              Y
# 247612  {'Friday': '20:0-22:0', 'Saturday': '10:0-23:3...              Y
#
# [247613 rows x 24 columns]

# %% [markdown]
# ### 2. Data Exploration
# Data exploration includes 2 part:
# 1. Flatten attributes inside column "Attributes" to new columns for validation purpose;
# 2. Check Emojis in the text column

# %%
#Flatten "Attributes" and add to new columns"
import ast
from pandas import json_normalize
ca_df['attributes'] = ca_df['attributes'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
#  flatten Json 
flattened_attributes = json_normalize(ca_df['attributes'])
# Combine the flattened attributes with the original DataFrame
ca_df = pd.concat([ca_df, flattened_attributes], axis=1)
for column in ['Ambience', 'GoodForMeal']:
    ca_df[column] = ca_df[column].fillna('{}')
    ca_df[column] = ca_df[column].apply(ast.literal_eval)
    flattened_attributes = json_normalize(ca_df[column])
    ca_df = pd.concat([ca_df, flattened_attributes], axis=1)
ca_df = ca_df.drop(['attributes','Ambience', 'GoodForMeal'], axis=1)
ca_df
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/capstone-proj/lib/python3.10/site-packages/IPython/lib/pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /opt/homebrew/Caskroom/miniconda/base/envs/capstone-proj/lib/python3.10/site-packages/IPython/core/formatters.py:344: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#         Unnamed: 0               review_id                 user_id  \
# 0             1375  pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw
# 1             1376  _Ub20uO1MKy4XOVPOdzpqw  lUYboGI6aFbZ0dX27pijpA
# 2             1377  -DjIfoNFAiT5J4kF9hXocQ  SrfDRvGKI8FQq9LCr0dQuQ
# 3             1378  URe-2Zlv7RoY4Ycr9JYVWw  SfMf7DEX7xT82OCcbZFsgQ
# 4             1379  tHP5ihPd_W9OzfkKEWdIwA  aH3AH7V9g60w4pt3LpJ1_Q
# ...            ...                     ...                     ...
# 247608     6990221  cKuP5pnvbvpn4UbaccVcdg  OVYb1El25BgVhgbXb4e-KA
# 247609     6990222  dZC87sZ1f2ntOf876_DDLg  9w5PoliouEyNikdy6DizqQ
# 247610     6990223  NCafkcXIvK7E965my4RpQg  GmuHOkMR80oW3sAuF-UsAw
# 247611     6990224  VxsNftGxRUDZcLD0Ns1wKg  VRXPOvlSydho0tYmSseKnQ
# 247612     6990225  beFM3Lm5Pj6Spr8x6RV9Cg  uoYuvbxTCB0eu1UF4sUTcA
#
#                    business_id  stars_x  useful  funny  cool  \
# 0       gebiRewfieSdtt17PTW6Zg        3       0      0     0
# 1       gebiRewfieSdtt17PTW6Zg        1       0      2     0
# 2       gebiRewfieSdtt17PTW6Zg        3       9      4     6
# 3       gebiRewfieSdtt17PTW6Zg        5       1      0     1
# 4       gebiRewfieSdtt17PTW6Zg        4       0      0     0
# ...                        ...      ...     ...    ...   ...
# 247608  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     0
# 247609  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     0
# 247610  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     0
# 247611  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     0
# 247612  XPkkWyAkkPeH-PqXmBMmpg        5       0      0     1
#
#                                                      text  \
# 0       Had a party of 6 here for hibachi. Our waitres...
# 1       Sat down over a half hour, only miso and drink...
# 2       Not bad. Sushi roll was good but options were ...
# 3       I'm very picky when it comes to Sushi. Quality...
# 4       Even though the sushi masters are not actually...
# ...                                                   ...
# 247608  Great experience with great people who are rea...
# 247609  I spent the week in Santa Barbara and had the ...
# 247610  Last summer, I had the pleasure of experiencin...
# 247611  Joseph and Teresa are super hosts.  You will f...
# 247612  I discovered Santa Barbara Tours and Experienc...
#
#                                  date  ... intimate romantic classy upscale  \
# 0       2016-07-25 07:31:06.000000000  ...    False    False   True   False
# 1       2017-06-28 01:04:59.000000000  ...    False    False   True   False
# 2       2017-01-14 23:31:35.000000000  ...    False    False   True   False
# 3       2016-07-14 23:09:38.000000000  ...    False    False   True   False
# 4       2014-11-30 07:35:54.000000000  ...    False    False   True   False
# ...                               ...  ...      ...      ...    ...     ...
# 247608  2021-06-22 21:41:07.000000000  ...      NaN      NaN    NaN     NaN
# 247609  2021-06-28 23:53:44.000000000  ...      NaN      NaN    NaN     NaN
# 247610  2021-07-06 19:15:56.000000000  ...      NaN      NaN    NaN     NaN
# 247611  2021-07-01 03:44:10.000000000  ...      NaN      NaN    NaN     NaN
# 247612  2021-07-27 20:41:20.000000000  ...      NaN      NaN    NaN     NaN
#
#         dessert  latenight  lunch  dinner  brunch  breakfast
# 0         False      False   True    True   False      False
# 1         False      False   True    True   False      False
# 2         False      False   True    True   False      False
# 3         False      False   True    True   False      False
# 4         False      False   True    True   False      False
# ...         ...        ...    ...     ...     ...        ...
# 247608      NaN        NaN    NaN     NaN     NaN        NaN
# 247609      NaN        NaN    NaN     NaN     NaN        NaN
# 247610      NaN        NaN    NaN     NaN     NaN        NaN
# 247611      NaN        NaN    NaN     NaN     NaN        NaN
# 247612      NaN        NaN    NaN     NaN     NaN        NaN
#
# [247613 rows x 74 columns]

# %%
# Calculate non-empty value rate for each of the column. We will take below 25% missing rate for consideration.
total_counts = ca_df.isin(['None']).sum() + ca_df.isna().sum()
non_Empty_rate = 1-total_counts/ca_df.shape[0]
non_Empty_rate
# Out:
# Unnamed: 0     1.000000
# review_id      1.000000
# user_id        1.000000
# business_id    1.000000
# stars_x        1.000000
#                  ...
# latenight      0.653992
# lunch          0.609847
# dinner         0.682266
# brunch         0.551207
# breakfast      0.619564
# Length: 74, dtype: float64

# %%
# %%time
import emot
emot_obj = emot.core.emot()
emojis = []
for text in ca_df['text']:
    emos = emot_obj.emoji(text)
    if len(emos.get('value')) >= 1:
        print(emos.get('value'))
    else:
        emojis.append(None)
# Out:
# ['‼']
# ['™']
# ['‼']
# ['‼']
# ['‼']
# ['®']
# ['‼']
# ['®']
# ['‼']
# ['™']
# ['‼', '‼']
# ['‼']
# ['™']
# ['‼', '‼', '‼']
# ['‼']
# ['‼', '‼']
# ['‼']
# ['™']
# ['‼']
# ['‼']
# ['‼', '‼']
# CPU times: user 2min 50s, sys: 107 ms, total: 2min 50s
# Wall time: 2min 50s

# %% [markdown]
# In our sentiment analysis, we took into consideration the handling of emojis. Emojis, to some extent, convey emotions, so we believed they could help on our analysis. However, during the initial processing, we only catched :bangbang:, ®, ™. Emojis observed didn't contribute significantly to expressing emotions. Therefore, in this analysis, we chose to filter out emojis as they were not deemed impactful.

# %% [markdown]
# ### 3.Data pre-processing
# Text need to consider some cases. We will perform the following steps:
# ###### 1). To Lower Case
# ###### 2). Tokenization
# ###### 3). Remove Stopwords
# ###### 4). Remove URL, Emails, Special Chars
# ###### 5). Stemming/Lemmatization
# ###### 6). Replace food related entities (sushi, roll, ) by a gernal word 'food'.

# %%
# %%time
from gensim.parsing.preprocessing import preprocess_string
# This method from gensim automatically does the 5 steps above. Note this method also remove Emoji.
ca_df['tokens'] = ca_df['text'].apply(lambda x :preprocess_string(x) ) # This method automatically does the 5 steps above
ca_df.head()
# Out:
# CPU times: user 33.9 s, sys: 174 ms, total: 34.1 s
# Wall time: 34.2 s
#    Unnamed: 0               review_id                 user_id  \
# 0        1375  pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw
# 1        1376  _Ub20uO1MKy4XOVPOdzpqw  lUYboGI6aFbZ0dX27pijpA
# 2        1377  -DjIfoNFAiT5J4kF9hXocQ  SrfDRvGKI8FQq9LCr0dQuQ
# 3        1378  URe-2Zlv7RoY4Ycr9JYVWw  SfMf7DEX7xT82OCcbZFsgQ
# 4        1379  tHP5ihPd_W9OzfkKEWdIwA  aH3AH7V9g60w4pt3LpJ1_Q
#
#               business_id  stars_x  useful  funny  cool  \
# 0  gebiRewfieSdtt17PTW6Zg        3       0      0     0
# 1  gebiRewfieSdtt17PTW6Zg        1       0      2     0
# 2  gebiRewfieSdtt17PTW6Zg        3       9      4     6
# 3  gebiRewfieSdtt17PTW6Zg        5       1      0     1
# 4  gebiRewfieSdtt17PTW6Zg        4       0      0     0
#
#                                                 text  \
# 0  Had a party of 6 here for hibachi. Our waitres...
# 1  Sat down over a half hour, only miso and drink...
# 2  Not bad. Sushi roll was good but options were ...
# 3  I'm very picky when it comes to Sushi. Quality...
# 4  Even though the sushi masters are not actually...
#
#                             date  ... romantic classy upscale dessert  \
# 0  2016-07-25 07:31:06.000000000  ...    False   True   False   False
# 1  2017-06-28 01:04:59.000000000  ...    False   True   False   False
# 2  2017-01-14 23:31:35.000000000  ...    False   True   False   False
# 3  2016-07-14 23:09:38.000000000  ...    False   True   False   False
# 4  2014-11-30 07:35:54.000000000  ...    False   True   False   False
#
#    latenight  lunch  dinner  brunch  breakfast  \
# 0      False   True    True   False      False
# 1      False   True    True   False      False
# 2      False   True    True   False      False
# 3      False   True    True   False      False
# 4      False   True    True   False      False
#
#                                               tokens
# 0  [parti, hibachi, waitress, brought, separ, sus...
# 1  [sat, half, hour, miso, drink, serv, wait, act...
# 2  [bad, sushi, roll, good, option, limit, hibach...
# 3  [picki, come, sushi, qualiti, fish, ingredi, i...
# 4  [sushi, master, actual, asian, good, sushi, pr...
#
# [5 rows x 75 columns]

# %% [markdown]
# ### 4.LDA and NMF Topic Modelling

# %% [markdown]
# For LDA and NMF model, we do 4 steps for each model. 1) Create dictionary and corpus for model; 2) build Model 3) plot Coherence plot for different topic number to find optimal topic number; 4) Combined with topic number and extracted topics, find optimized model. 5) Visualize the topics

# %%
import gensim
from gensim.models.ldamulticore import LdaMulticore

random_state = 42


# Step 1: Create Dictionary and Bow Corpus
dictionary = gensim.corpora.Dictionary(ca_df['tokens'])
#filter extreme conditions
dictionary.filter_extremes(no_below=5, no_above=0.5)
corpus = [dictionary.doc2bow(text) for text in ca_df['tokens']]

# Step 2: Build Topic Model
# lda_model = gensim.models.LdaMulticore(corpus=corpus,
#                                        id2word=dictionary,
#                                        num_topics=15, 
#                                        random_state=random_state,
#                                        chunksize=2000,
#                                        passes=20,
#                                        workers=3)

# %%
# Step 3: Find the Optimal Number of Topics
import matplotlib.pyplot as plt
from gensim.models import CoherenceModel
from scipy.sparse import csc_matrix
from tqdm import tqdm

def compute_coherence_values(modelname, dictionary, corpus, texts, start, limit, step):
    """
    helper function
    return 2 lists: 1. list for model; 2. list for coherence vaules
    """
    coherence_values = []
    model_list = []
    # Initialize tqdm progress bar
    pbar = tqdm(range(start, limit, step), desc=f'Computing coherence for {modelname}')
    
    for num_topics in pbar:  # Iterate over topics with tqdm progress bar
        if modelname == "LDA":
            cur_model = LdaMulticore(corpus=corpus,
                        id2word=dictionary,
                         num_topics=num_topics,
                         random_state=random_state,
                         chunksize=2000,
                         passes=20,
                         workers=3)
        elif modelname == 'NMF':
            if isinstance(corpus, csc_matrix):  # Check with csc_matrix
                cur_model = Nmf(corpus=corpus,
                            id2word=dictionary,
                            num_topics=num_topics,
                            random_state=random_state,
                            chunksize=2000,
                            passes=20)
            else:
                cur_model = Nmf(corpus=corpus,
                            id2word=dictionary,
                            num_topics=num_topics,
                            random_state=random_state,
                            chunksize=2000,
                            passes=20)
        model_list.append(cur_model)
        coherencemodel = CoherenceModel(model=cur_model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
        # Update tqdm progress bar description
        pbar.set_description(f'Computing coherence for {modelname}, Num Topics: {num_topics}')

    return model_list, coherence_values

def plot_coherences_topics(modelName, start, limit, step, model_list, coherence_values):
    """
    Create a plot as shown above of coherence for the topic models created with num_topics
    """
    for m, cv in zip(range(start, limit, step), coherence_values):
        print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
    
    # Select the model and number of topics with the highest coherence score
    max_coherence_value = max(coherence_values)
    optimal_index = coherence_values.index(max_coherence_value)
    optimal_model = model_list[optimal_index]
    optimal_num_topics = optimal_index*step + start
    print("Optimal Number of Topics:", optimal_num_topics)
    
    # Step 4: Print the Topics of the Optimal Model
    topics = optimal_model.print_topics(num_words=15)
    for topic in topics:
        print(topic)
    x = range(start, limit, step)  # Number of topics
    plt.plot(x, coherence_values)
    plt.xlabel("Number of Topics")
    plt.ylabel("Coherence score")
    plt.title("Coherence Score vs Number of Topics for " + modelName + " model")
    plt.xticks(x)  # Show all the x-ticks (number of topics)
    plt.show()

# %% [markdown]
# When choosing the number of topics for LDA or NMF model, it's important to consider both the coherence scores and domain knowledge or human intuition. From the review dataset, we know there are multiple aspects to talk about. Therefore, I prefer a larger topic number rather than a smaller one. Let try to plot the coherence scores from 10 to 30 topics

# %% [markdown]
# #### LDA model
# let's try one LDA model with a random topic number to see the result

# %%
# %%time
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=dictionary,
                                       num_topics=26, 
                                       random_state=random_state,
                                       chunksize=2000,
                                       passes=20,
                                       workers=3)
# Out:
# CPU times: user 1min 18s, sys: 24.9 s, total: 1min 43s
# Wall time: 3min 6s

# %%
for topic in lda_model.print_topics(num_words=15):
    print(topic)
# Out:
# (3, '0.050*"beer" + 0.045*"bar" + 0.040*"drink" + 0.025*"place" + 0.024*"great" + 0.020*"night" + 0.016*"good" + 0.014*"fun" + 0.014*"bartend" + 0.013*"music" + 0.012*"like" + 0.011*"cool" + 0.011*"select" + 0.010*"cocktail" + 0.009*"plai"')
# (14, '0.084*"sandwich" + 0.073*"salad" + 0.039*"chees" + 0.031*"bread" + 0.026*"chicken" + 0.020*"order" + 0.016*"tomato" + 0.016*"lunch" + 0.015*"fresh" + 0.014*"good" + 0.012*"dress" + 0.010*"pickl" + 0.010*"soup" + 0.009*"turkei" + 0.009*"grill"')
# (16, '0.127*"roll" + 0.094*"sushi" + 0.043*"salmon" + 0.041*"tuna" + 0.030*"fish" + 0.028*"ahi" + 0.025*"fresh" + 0.017*"japanes" + 0.016*"poke" + 0.013*"mahi" + 0.012*"spici" + 0.012*"order" + 0.011*"sashimi" + 0.010*"jane" + 0.010*"chef"')
# (7, '0.189*"pizza" + 0.038*"order" + 0.033*"cupcak" + 0.030*"wing" + 0.028*"crust" + 0.018*"deliveri" + 0.017*"top" + 0.017*"chees" + 0.015*"slice" + 0.015*"sauc" + 0.012*"deliv" + 0.011*"good" + 0.009*"deep" + 0.008*"frost" + 0.008*"dough"')
# (17, '0.019*"custom" + 0.017*"ask" + 0.015*"said" + 0.015*"order" + 0.013*"manag" + 0.013*"time" + 0.012*"servic" + 0.011*"told" + 0.010*"peopl" + 0.009*"want" + 0.009*"work" + 0.009*"know" + 0.008*"call" + 0.008*"rude" + 0.007*"like"')
# (15, '0.039*"seat" + 0.036*"outsid" + 0.032*"patio" + 0.027*"park" + 0.023*"street" + 0.022*"outdoor" + 0.022*"nice" + 0.022*"tabl" + 0.020*"insid" + 0.019*"sit" + 0.018*"great" + 0.017*"locat" + 0.017*"area" + 0.016*"beach" + 0.016*"state"')
# (2, '0.054*"room" + 0.038*"stai" + 0.026*"hotel" + 0.013*"night" + 0.012*"clean" + 0.011*"bathroom" + 0.009*"walk" + 0.009*"nice" + 0.009*"beach" + 0.008*"bed" + 0.008*"check" + 0.008*"staff" + 0.007*"locat" + 0.006*"inn" + 0.006*"like"')
# (25, '0.110*"coffe" + 0.030*"tea" + 0.028*"shop" + 0.025*"pastri" + 0.023*"donut" + 0.020*"drink" + 0.018*"bagel" + 0.018*"latt" + 0.017*"croissant" + 0.016*"good" + 0.015*"cup" + 0.014*"bakeri" + 0.013*"milk" + 0.010*"morn" + 0.009*"starbuck"')
# (0, '0.061*"fish" + 0.043*"seafood" + 0.038*"crab" + 0.027*"view" + 0.026*"lobster" + 0.026*"clam" + 0.026*"shrimp" + 0.021*"chowder" + 0.020*"good" + 0.019*"fresh" + 0.019*"oyster" + 0.019*"chip" + 0.012*"fri" + 0.012*"calamari" + 0.011*"cake"')
# (23, '0.030*"chicken" + 0.029*"dish" + 0.027*"rice" + 0.024*"spici" + 0.023*"noodl" + 0.021*"thai" + 0.020*"order" + 0.019*"soup" + 0.019*"food" + 0.019*"flavor" + 0.016*"sauc" + 0.015*"curri" + 0.013*"like" + 0.013*"good" + 0.012*"bowl"')
# (21, '0.064*"taco" + 0.042*"burrito" + 0.038*"salsa" + 0.035*"mexican" + 0.021*"food" + 0.019*"chip" + 0.019*"order" + 0.016*"good" + 0.014*"tortilla" + 0.014*"bean" + 0.012*"nacho" + 0.012*"best" + 0.011*"enchilada" + 0.011*"chicken" + 0.011*"rice"')
# (24, '0.073*"price" + 0.066*"good" + 0.062*"food" + 0.031*"servic" + 0.030*"great" + 0.027*"portion" + 0.023*"place" + 0.022*"qualiti" + 0.021*"reason" + 0.015*"menu" + 0.015*"nice" + 0.014*"small" + 0.012*"size" + 0.012*"littl" + 0.012*"worth"')
# (19, '0.081*"happi" + 0.055*"hour" + 0.024*"birthdai" + 0.024*"parti" + 0.022*"wed" + 0.017*"dai" + 0.016*"thank" + 0.016*"event" + 0.015*"special" + 0.015*"celebr" + 0.015*"dinner" + 0.015*"guest" + 0.014*"cake" + 0.014*"work" + 0.012*"cater"')
# (18, '0.033*"year" + 0.022*"time" + 0.014*"locat" + 0.014*"local" + 0.013*"store" + 0.012*"new" + 0.012*"old" + 0.012*"market" + 0.011*"like" + 0.010*"open" + 0.009*"town" + 0.009*"best" + 0.009*"love" + 0.009*"ago" + 0.008*"come"')
# (5, '0.023*"dish" + 0.017*"dinner" + 0.016*"dessert" + 0.013*"restaur" + 0.013*"meal" + 0.012*"sauc" + 0.012*"delici" + 0.011*"pasta" + 0.011*"flavor" + 0.011*"order" + 0.010*"appet" + 0.010*"bread" + 0.010*"perfect" + 0.009*"cook" + 0.009*"salad"')
# (8, '0.030*"restaur" + 0.018*"experi" + 0.016*"review" + 0.015*"dine" + 0.012*"menu" + 0.010*"chef" + 0.008*"wai" + 0.007*"san" + 0.007*"coast" + 0.007*"visit" + 0.007*"star" + 0.007*"feel" + 0.007*"yelp" + 0.006*"best" + 0.006*"expect"')
# (9, '0.039*"food" + 0.016*"order" + 0.016*"place" + 0.014*"servic" + 0.014*"charg" + 0.014*"disappoint" + 0.013*"like" + 0.013*"bad" + 0.012*"eat" + 0.011*"tast" + 0.010*"time" + 0.009*"star" + 0.008*"better" + 0.008*"cold" + 0.008*"monei"')
# (6, '0.045*"order" + 0.035*"food" + 0.035*"wait" + 0.034*"tabl" + 0.025*"came" + 0.023*"time" + 0.022*"minut" + 0.021*"servic" + 0.019*"server" + 0.019*"ask" + 0.016*"drink" + 0.015*"took" + 0.015*"restaur" + 0.015*"waitress" + 0.013*"got"')
# (11, '0.053*"cream" + 0.045*"ic" + 0.037*"flavor" + 0.027*"chocol" + 0.017*"cake" + 0.017*"sweet" + 0.014*"bowl" + 0.013*"cooki" + 0.013*"tast" + 0.012*"like" + 0.011*"strawberri" + 0.010*"fruit" + 0.009*"juic" + 0.008*"scoop" + 0.008*"butter"')
# (10, '0.120*"fri" + 0.117*"burger" + 0.026*"dog" + 0.022*"onion" + 0.018*"mesa" + 0.016*"chees" + 0.016*"bun" + 0.014*"ring" + 0.014*"hot" + 0.012*"baklava" + 0.012*"order" + 0.011*"good" + 0.011*"potato" + 0.010*"sweet" + 0.009*"scott"')

# %% [markdown]
# ---------------------------------------------
# We extract the topics names by chatGPT and validated by manually inspection
# Here is the topic name for topics:
# Topic 3: **Nightlife and Drinks**
# Topic 14: Lunch Menu
# Topic 16: Sushi and Rolls
# Topic 7: Pizza and Fast Food
# Topic 17: Customer Service
# Topic 15: **Outdoor Seating**
# Topic 2: Hotel Accommodations
# Topic 25: Coffee and Pastries
# Topic 0: **Seafood Selection**
# Topic 23: Asian Cuisine
# Topic 21: Mexican Dishes
# Topic 24: **Value and Pricing**
# Topic 19: Social Events
# Topic 18: Local Markets
# Topic 5: **Fine Dining**
# Topic 8: **Restaurant Experience**
# Topic 9: **Food Quality**
# Topic 6: **Waiting Times**
# Topic 11: Desserts and Sweets
# Topic 10: Burgers and Fries
# --------------------------------------------------
# The aspects are able to extracted are highlighted by bold. Rest of topics are more about a specific cuisine. Like BBQ, Mexican cuisine, Pizza. To resolve the problem topics are more cuisine oriented, we replace words around Cuisines by a general word "food"

# %%
# %time
# to resolve the problem topics are more cuisine oriented, we replace words around Cuisines by a general word "food"
food_labels_set = ['fish', "sushi", "roll", "seafood", "crab", "fresh", "shrimp", "lobster" , "clam", "taco", "burrito", "salsa", "mexican","indian", "chip", "pizza", "vegan", "chicken", "sandwich", "fri", "burger", "salad", "chees","bread", "donut", "chocol", "coffe", "ic", "cream" , "salmon", "ahi", "ramen", "octopu", "egg", "toast", "potato", "bacon",  "pancak", "meat", "grill", "hibachi", "wing","pork","steak", "rib","chowder", "oyster"]
ca_df['tokens_removed_labels'] = ca_df['tokens'].apply(lambda x: [word if word not in food_labels_set else "food" for word in x])
ca_df.head()
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 4.29 µs
#    Unnamed: 0               review_id                 user_id  \
# 0        1375  pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw
# 1        1376  _Ub20uO1MKy4XOVPOdzpqw  lUYboGI6aFbZ0dX27pijpA
# 2        1377  -DjIfoNFAiT5J4kF9hXocQ  SrfDRvGKI8FQq9LCr0dQuQ
# 3        1378  URe-2Zlv7RoY4Ycr9JYVWw  SfMf7DEX7xT82OCcbZFsgQ
# 4        1379  tHP5ihPd_W9OzfkKEWdIwA  aH3AH7V9g60w4pt3LpJ1_Q
#
#               business_id  stars_x  useful  funny  cool  \
# 0  gebiRewfieSdtt17PTW6Zg        3       0      0     0
# 1  gebiRewfieSdtt17PTW6Zg        1       0      2     0
# 2  gebiRewfieSdtt17PTW6Zg        3       9      4     6
# 3  gebiRewfieSdtt17PTW6Zg        5       1      0     1
# 4  gebiRewfieSdtt17PTW6Zg        4       0      0     0
#
#                                                 text  \
# 0  Had a party of 6 here for hibachi. Our waitres...
# 1  Sat down over a half hour, only miso and drink...
# 2  Not bad. Sushi roll was good but options were ...
# 3  I'm very picky when it comes to Sushi. Quality...
# 4  Even though the sushi masters are not actually...
#
#                             date  ... classy upscale dessert latenight  lunch  \
# 0  2016-07-25 07:31:06.000000000  ...   True   False   False     False   True
# 1  2017-06-28 01:04:59.000000000  ...   True   False   False     False   True
# 2  2017-01-14 23:31:35.000000000  ...   True   False   False     False   True
# 3  2016-07-14 23:09:38.000000000  ...   True   False   False     False   True
# 4  2014-11-30 07:35:54.000000000  ...   True   False   False     False   True
#
#    dinner  brunch  breakfast  \
# 0    True   False      False
# 1    True   False      False
# 2    True   False      False
# 3    True   False      False
# 4    True   False      False
#
#                                               tokens  \
# 0  [parti, hibachi, waitress, brought, separ, sus...
# 1  [sat, half, hour, miso, drink, serv, wait, act...
# 2  [bad, sushi, roll, good, option, limit, hibach...
# 3  [picki, come, sushi, qualiti, fish, ingredi, i...
# 4  [sushi, master, actual, asian, good, sushi, pr...
#
#                                tokens_removed_labels
# 0  [parti, food, waitress, brought, separ, food, ...
# 1  [sat, half, hour, miso, drink, serv, wait, act...
# 2  [bad, food, food, good, option, limit, food, f...
# 3  [picki, come, food, qualiti, food, ingredi, im...
# 4  [food, master, actual, asian, good, food, pric...
#
# [5 rows x 76 columns]

# %% [markdown]
# Do the main four steps for the post-processed tokens instead of tokens

# %%
import gensim
from gensim.models import Nmf
from gensim.corpora.dictionary import Dictionary
#1.Create Dictionary and Bow Corpus for post-processed text
# Create a corpus from a list of texts
dictionary_removed_labels = gensim.corpora.Dictionary(ca_df['tokens_removed_labels'])
#filter extreme conditions
dictionary_removed_labels.filter_extremes(no_below=5, no_above=0.5)
corpus_removed_labels = [dictionary_removed_labels.doc2bow(text) for text in ca_df['tokens_removed_labels']]

# %% [markdown]
# Let's find the optimal topic number by coherence score

# %%
# This cell takes a lone time, 1 hour around
LDA_model_list, LDA_coherence_values = compute_coherence_values(modelname="LDA",dictionary=dictionary_removed_labels, corpus=corpus_removed_labels, texts=ca_df['tokens_removed_labels'], start=18, limit=31, step=1)
# Out:
# Computing coherence for LDA, Num Topics: 30: 100%|██████████| 13/13 [43:03<00:00, 198.70s/it]

# %%
plot_coherences_topics("LDA", 18, 31, 1, LDA_model_list, LDA_coherence_values)
# Out:
# Num Topics = 18  has Coherence Value of 0.489
# Num Topics = 19  has Coherence Value of 0.5037
# Num Topics = 20  has Coherence Value of 0.487
# Num Topics = 21  has Coherence Value of 0.5279
# Num Topics = 22  has Coherence Value of 0.494
# Num Topics = 23  has Coherence Value of 0.4886
# Num Topics = 24  has Coherence Value of 0.4973
# Num Topics = 25  has Coherence Value of 0.5171
# Num Topics = 26  has Coherence Value of 0.5154
# Num Topics = 27  has Coherence Value of 0.5019
# Num Topics = 28  has Coherence Value of 0.5093
# Num Topics = 29  has Coherence Value of 0.5126
# Num Topics = 30  has Coherence Value of 0.5042
# Optimal Number of Topics: 21
# (16, '0.184*"santa" + 0.174*"barbara" + 0.035*"best" + 0.029*"restaur" + 0.023*"visit" + 0.017*"favorit" + 0.011*"gem" + 0.011*"local" + 0.011*"place" + 0.010*"san" + 0.009*"stop" + 0.009*"trip" + 0.009*"year" + 0.009*"area" + 0.009*"live"')
# (20, '0.062*"street" + 0.057*"park" + 0.053*"locat" + 0.045*"state" + 0.020*"lot" + 0.017*"walk" + 0.015*"right" + 0.012*"shop" + 0.012*"drive" + 0.011*"lunch" + 0.011*"stop" + 0.011*"coast" + 0.011*"easi" + 0.010*"conveni" + 0.010*"beach"')
# (2, '0.025*"flavor" + 0.023*"sauc" + 0.013*"delici" + 0.012*"perfect" + 0.012*"onion" + 0.012*"sweet" + 0.012*"perfectli" + 0.010*"cook" + 0.009*"crispi" + 0.007*"tender" + 0.007*"nice" + 0.007*"serv" + 0.007*"tomato" + 0.007*"season" + 0.007*"light"')
# (4, '0.101*"breakfast" + 0.036*"brunch" + 0.028*"french" + 0.019*"good" + 0.019*"morn" + 0.017*"order" + 0.016*"delici" + 0.016*"benedict" + 0.015*"cafe" + 0.014*"croissant" + 0.014*"pastri" + 0.012*"sundai" + 0.011*"mari" + 0.011*"bloodi" + 0.011*"muffin"')
# (1, '0.027*"rice" + 0.025*"spici" + 0.023*"dish" + 0.023*"soup" + 0.021*"order" + 0.020*"noodl" + 0.020*"thai" + 0.016*"good" + 0.016*"curri" + 0.015*"flavor" + 0.014*"restaur" + 0.013*"like" + 0.013*"bowl" + 0.011*"sauc" + 0.011*"chines"')
# (0, '0.057*"place" + 0.031*"time" + 0.030*"love" + 0.024*"best" + 0.022*"amaz" + 0.022*"try" + 0.021*"good" + 0.021*"come" + 0.015*"definit" + 0.014*"delici" + 0.014*"eat" + 0.013*"great" + 0.011*"recommend" + 0.010*"favorit" + 0.010*"dai"')
# (10, '0.039*"order" + 0.035*"wait" + 0.031*"tabl" + 0.022*"minut" + 0.020*"time" + 0.020*"servic" + 0.018*"came" + 0.018*"ask" + 0.014*"server" + 0.012*"restaur" + 0.012*"took" + 0.012*"seat" + 0.011*"drink" + 0.011*"got" + 0.010*"arriv"')
# (3, '0.048*"seat" + 0.044*"outsid" + 0.043*"patio" + 0.033*"view" + 0.030*"outdoor" + 0.026*"sit" + 0.025*"nice" + 0.023*"tabl" + 0.023*"insid" + 0.021*"great" + 0.020*"beach" + 0.019*"enjoi" + 0.017*"area" + 0.015*"beauti" + 0.015*"place"')
# (14, '0.029*"place" + 0.026*"like" + 0.026*"good" + 0.021*"price" + 0.013*"star" + 0.012*"better" + 0.010*"tast" + 0.010*"pretti" + 0.010*"qualiti" + 0.010*"think" + 0.009*"review" + 0.008*"thing" + 0.008*"restaur" + 0.008*"expect" + 0.007*"bad"')
# (18, '0.026*"shop" + 0.021*"store" + 0.020*"market" + 0.020*"cake" + 0.019*"tea" + 0.015*"cupcak" + 0.013*"latt" + 0.012*"drink" + 0.011*"like" + 0.010*"local" + 0.009*"sweet" + 0.009*"milk" + 0.008*"bakeri" + 0.008*"cup" + 0.008*"select"')
# (7, '0.029*"servic" + 0.023*"amaz" + 0.022*"great" + 0.020*"recommend" + 0.020*"restaur" + 0.019*"experi" + 0.019*"delici" + 0.014*"dinner" + 0.014*"wonder" + 0.013*"love" + 0.013*"highli" + 0.013*"staff" + 0.012*"excel" + 0.011*"server" + 0.011*"thank"')
# (6, '0.058*"drink" + 0.056*"bar" + 0.033*"night" + 0.027*"happi" + 0.027*"hour" + 0.018*"bartend" + 0.018*"cocktail" + 0.016*"music" + 0.015*"wed" + 0.014*"fun" + 0.012*"great" + 0.011*"friend" + 0.011*"event" + 0.009*"live" + 0.008*"peopl"')
# (11, '0.099*"beer" + 0.023*"dog" + 0.022*"bbq" + 0.017*"good" + 0.016*"game" + 0.016*"select" + 0.014*"tap" + 0.013*"great" + 0.013*"kid" + 0.012*"tip" + 0.012*"breweri" + 0.011*"tri" + 0.011*"plai" + 0.011*"like" + 0.010*"hot"')
# (15, '0.119*"wine" + 0.049*"tast" + 0.028*"tour" + 0.017*"bottl" + 0.017*"wineri" + 0.016*"great" + 0.015*"glass" + 0.012*"dai" + 0.012*"knowledg" + 0.010*"time" + 0.010*"experi" + 0.010*"room" + 0.009*"fun" + 0.009*"recommend" + 0.007*"enjoi"')
# (13, '0.017*"custom" + 0.015*"order" + 0.015*"time" + 0.014*"ask" + 0.012*"said" + 0.012*"servic" + 0.011*"manag" + 0.010*"work" + 0.009*"like" + 0.009*"know" + 0.009*"want" + 0.009*"told" + 0.008*"peopl" + 0.007*"rude" + 0.007*"call"')
# (9, '0.100*"great" + 0.055*"good" + 0.053*"place" + 0.051*"servic" + 0.043*"friendli" + 0.030*"staff" + 0.028*"nice" + 0.023*"love" + 0.020*"price" + 0.017*"delici" + 0.017*"super" + 0.016*"definit" + 0.015*"atmospher" + 0.011*"excel" + 0.011*"come"')
# (5, '0.046*"covid" + 0.035*"clean" + 0.030*"buffet" + 0.022*"dirti" + 0.020*"restroom" + 0.019*"safe" + 0.019*"mask" + 0.018*"social" + 0.017*"wear" + 0.017*"hand" + 0.015*"distanc" + 0.015*"plastic" + 0.015*"wash" + 0.014*"pro" + 0.013*"pharmaci"')
# (19, '0.045*"order" + 0.031*"good" + 0.020*"got" + 0.017*"like" + 0.014*"came" + 0.014*"dish" + 0.014*"tast" + 0.013*"sauc" + 0.012*"pasta" + 0.012*"meal" + 0.010*"plate" + 0.010*"dinner" + 0.009*"eat" + 0.009*"disappoint" + 0.008*"cook"')
# (8, '0.062*"room" + 0.045*"stai" + 0.030*"hotel" + 0.013*"night" + 0.013*"bathroom" + 0.011*"clean" + 0.010*"nice" + 0.009*"bed" + 0.009*"check" + 0.009*"walk" + 0.008*"pool" + 0.008*"staff" + 0.008*"beach" + 0.007*"inn" + 0.007*"book"')
# (17, '0.032*"order" + 0.031*"bean" + 0.022*"rice" + 0.021*"tortilla" + 0.019*"good" + 0.018*"nacho" + 0.018*"enchilada" + 0.016*"flavor" + 0.016*"delici" + 0.015*"margarita" + 0.015*"beef" + 0.015*"lo" + 0.014*"agav" + 0.014*"guacamol" + 0.013*"bar"')

# %%
# Mannually inspect several topic, see which topic number make more sense to human 
LDA_topic_num_list = [ 21, 25, 26, 29]
for idx in LDA_topic_num_list:
    model = LDA_model_list[idx - 18]
    print("="*20)
    print("Topic Number: ", idx)
    sorted_topics = sorted(model.print_topics(num_words=15), key=lambda x: x[0])

# Print the sorted topics
#     for topic in sorted_topics:
#         print(topic)
# Out:
# ====================
# Topic Number:  21
# ====================
# Topic Number:  25
# ====================
# Topic Number:  26
# ====================
# Topic Number:  29

# %%
# by inspection, we take topic number 29 for the optimal model
LDA_optimal_model = LDA_model_list[29 - 18]
# LDA_optimal_model.top_topics(corpus_removed_labels)

# %% [markdown]
# alpha and eta are hyperparameters that affect sparsity of the document-topic (theta) and topic-word (lambda) distributions. We will let these be the default values for now(default value is 1/num_topics)
#
# Alpha is the per document topic distribution.
#
# High alpha: Every document has a mixture of all topics(documents appear similar to each other).
# Low alpha: Every document has a mixture of very few topics
# Eta is the per topic word distribution.
#
# High eta: Each topic has a mixture of most words(topics appear similar to each other).
# Low eta: Each topic has a mixture of few words.
#
# We set as auto.

# %%
print("Alpha:", LDA_optimal_model.alpha)
print("Eta:", LDA_optimal_model.eta)
# Out:
# Alpha: [0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  0.03448276 0.03448276 0.03448276 0.03448276 0.03448276]
# Eta: [0.03448276 0.03448276 0.03448276 ... 0.03448276 0.03448276 0.03448276]

# %% [markdown]
# ###### Visualize LAD model result

# %%
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
def create_heatmap(top_topics, y_label):
    # avg_coherences = [f'Topic {idx+1}\n({round(i[1],2)})' for idx, i in enumerate(top_topics)]
    matplotlib.rcParams.update({'font.size': 16})
    result_lst = []
    annot_lst = []
    for idx, row in enumerate(top_topics):
        result_lst.append([])
        annot_lst.append([])
        for j, k in row[0][:10]:
            result_lst[idx].append(round(j,4))
            annot_lst[idx].append(f'''{k}\n{str(round(j,4))}''')
    plt.figure(figsize=(25,35)) 
    plt.title("Heatmap for Topic Words")
    sns.heatmap(pd.DataFrame(result_lst),annot=pd.DataFrame(annot_lst),fmt='',cmap='YlGnBu',
               xticklabels = False, 
                yticklabels = y_label, 
                annot_kws={"size": 16}
                )
LDA_topic_list = [
    "Topic 1: Outdoor Seating and Ambiance",
    "Topic 2: General Favorites",
    "Topic 3: Disappointing Experiences",
    "Topic 4: Service Experience",
    "Topic 5: Friendly Service",
    "Topic 6: Customer Service Issues",
    "Topic 7: Pricing",
    "Topic 8: Dining Experience",
    "Topic 9: Food Flavor",
    "Topic 10: Gluten-Free",
    "Topic 11: Italian Cuisine",
    "Topic 12: Wine Tour and Tasting",
    "Topic 13: Waiting Time and Parking",
    "Topic 14: Vegetarian Options",
    "Topic 15: Accommodation and Event Setting",
    "Topic 16: Bar and Nightlife",
    "Topic 17: Santa Barbara and Visiting",
    "Topic 18: Happy Hour",
    "Topic 19: Local Shop",
    "Topic 20: Family Time",
    "Topic 21: Wine Selections",
    "Topic 22: Mexican Cuisine",  
    "Topic 23: Breakfast Specials",
    "Topic 24: Location, View",
    "Topic 25: Healthy Eats",
    "Topic 26: Flavor and Ingredients",
    "Topic 27: Tea and Thai Snake",
    "Topic 28: Cleanliness and Covid",
    "Topic 29: Coastal Cuisine."
]


create_heatmap(LDA_optimal_model.top_topics(corpus_removed_labels), LDA_topic_list)

# %% [markdown]
# We find some interesting topics: Topic 11 and Topic 14, Gluten-free and vegetarian option are popular in ca restaurants which are absent in our training dataset; Topic 28, cleanliness and covid is a new topic since 2019.People are more care about the Covid Precautions and cleanliness, which may be a new aspect for restaurants to consider.
#
# ** 21 Labels Extracted from LDA model:  Seating, Ambiance,Experience, Waiting Time, Service, Food Taste, Quality, Order, Food Flavor, Gluten-Free Options, Pricing, Vegetarian Options, Nightlife, Events and Setting, Good for Group, Kid friendly, Healthy Options, Location, View, Happy Hour, Cleanliness and Covid Precautions **

# %% [markdown]
# ##### NMF Model

# %%
# %%time
from gensim.models import Nmf
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

NMF_model_list, NMF_coherence_values = compute_coherence_values(modelname="NMF", dictionary=dictionary_removed_labels, corpus=corpus_removed_labels, texts=ca_df['tokens_removed_labels'], start=18, limit=31, step=1)
# Out:
# Computing coherence for NMF, Num Topics: 30: 100%|██████████| 13/13 [38:02<00:00, 175.61s/it]
# CPU times: user 4h 58min 36s, sys: 1h 43min 17s, total: 6h 41min 53s
# Wall time: 38min 2s

# %% [markdown]
# plot the coherence score for NMF model

# %%
plot_coherences_topics("NMF", 18, 31, 1, NMF_model_list, NMF_coherence_values)
# Out:
# Num Topics = 18  has Coherence Value of 0.4697
# Num Topics = 19  has Coherence Value of 0.4607
# Num Topics = 20  has Coherence Value of 0.4578
# Num Topics = 21  has Coherence Value of 0.4621
# Num Topics = 22  has Coherence Value of 0.4774
# Num Topics = 23  has Coherence Value of 0.4688
# Num Topics = 24  has Coherence Value of 0.4633
# Num Topics = 25  has Coherence Value of 0.4599
# Num Topics = 26  has Coherence Value of 0.4757
# Num Topics = 27  has Coherence Value of 0.474
# Num Topics = 28  has Coherence Value of 0.4625
# Num Topics = 29  has Coherence Value of 0.4705
# Num Topics = 30  has Coherence Value of 0.4721
# Optimal Number of Topics: 22
# (17, '0.015*"star" + 0.015*"menu" + 0.014*"better" + 0.014*"night" + 0.014*"price" + 0.013*"dinner" + 0.011*"friend" + 0.011*"thing" + 0.011*"experi" + 0.011*"hour" + 0.011*"happi" + 0.010*"meal" + 0.010*"review" + 0.007*"think" + 0.007*"wai"')
# (7, '0.145*"like" + 0.023*"tast" + 0.013*"look" + 0.011*"feel" + 0.011*"flavor" + 0.008*"sauc" + 0.007*"think" + 0.007*"thing" + 0.005*"try" + 0.005*"know" + 0.005*"felt" + 0.005*"sweet" + 0.005*"pretti" + 0.004*"better" + 0.004*"wasn"')
# (8, '0.024*"eat" + 0.023*"littl" + 0.017*"locat" + 0.016*"lot" + 0.016*"park" + 0.013*"nice" + 0.013*"breakfast" + 0.012*"street" + 0.010*"friendli" + 0.009*"spot" + 0.009*"area" + 0.008*"lunch" + 0.008*"seat" + 0.008*"menu" + 0.008*"right"')
# (0, '0.134*"restaur" + 0.023*"dish" + 0.014*"menu" + 0.010*"dine" + 0.009*"serv" + 0.008*"meal" + 0.008*"dinner" + 0.007*"sauc" + 0.006*"tabl" + 0.006*"cook" + 0.005*"eat" + 0.005*"waiter" + 0.005*"favorit" + 0.005*"reserv" + 0.005*"experi"')
# (4, '0.027*"want" + 0.027*"said" + 0.020*"ask" + 0.017*"custom" + 0.013*"manag" + 0.013*"know" + 0.013*"told" + 0.010*"look" + 0.009*"went" + 0.009*"work" + 0.009*"peopl" + 0.008*"call" + 0.007*"busi" + 0.007*"owner" + 0.007*"rude"')
# (15, '0.166*"santa" + 0.158*"barbara" + 0.020*"visit" + 0.011*"stop" + 0.009*"trip" + 0.009*"favorit" + 0.007*"tour" + 0.007*"dai" + 0.007*"local" + 0.006*"area" + 0.006*"live" + 0.006*"locat" + 0.005*"downtown" + 0.005*"year" + 0.005*"yelp"')
# (9, '0.092*"drink" + 0.060*"bar" + 0.024*"beer" + 0.014*"bartend" + 0.010*"peopl" + 0.010*"night" + 0.010*"happi" + 0.010*"tabl" + 0.010*"hour" + 0.010*"seat" + 0.009*"cocktail" + 0.008*"sit" + 0.008*"friend" + 0.008*"enjoi" + 0.008*"nice"')
# (12, '0.060*"room" + 0.026*"stai" + 0.022*"hotel" + 0.013*"night" + 0.011*"dai" + 0.010*"staff" + 0.010*"check" + 0.010*"nice" + 0.008*"breakfast" + 0.008*"bed" + 0.008*"pool" + 0.007*"beach" + 0.006*"desk" + 0.006*"walk" + 0.006*"clean"')
# (13, '0.209*"love" + 0.020*"delici" + 0.012*"favorit" + 0.010*"friendli" + 0.010*"come" + 0.009*"perfect" + 0.008*"staff" + 0.007*"absolut" + 0.007*"super" + 0.007*"enjoi" + 0.006*"husband" + 0.006*"flavor" + 0.006*"sweet" + 0.005*"wonder" + 0.005*"atmospher"')
# (16, '0.085*"bowl" + 0.026*"flavor" + 0.013*"rice" + 0.013*"sauc" + 0.011*"acai" + 0.010*"noodl" + 0.009*"tast" + 0.008*"top" + 0.008*"come" + 0.008*"soup" + 0.007*"try" + 0.007*"spici" + 0.006*"smoothi" + 0.006*"serv" + 0.006*"sweet"')
# (18, '0.201*"got" + 0.016*"flavor" + 0.013*"went" + 0.011*"friend" + 0.010*"littl" + 0.010*"wasn" + 0.010*"sauc" + 0.009*"pretti" + 0.009*"try" + 0.007*"tast" + 0.007*"super" + 0.007*"husband" + 0.007*"right" + 0.006*"think" + 0.005*"sweet"')
# (1, '0.321*"time" + 0.014*"visit" + 0.014*"long" + 0.011*"second" + 0.010*"come" + 0.009*"year" + 0.008*"went" + 0.006*"go" + 0.006*"dai" + 0.006*"sure" + 0.006*"busi" + 0.006*"lunch" + 0.005*"week" + 0.005*"try" + 0.005*"tri"')
# (10, '0.349*"good" + 0.024*"pretti" + 0.010*"price" + 0.010*"nice" + 0.007*"sauc" + 0.007*"overal" + 0.007*"bit" + 0.006*"tasti" + 0.006*"flavor" + 0.006*"beer" + 0.006*"thing" + 0.006*"tri" + 0.005*"portion" + 0.005*"littl" + 0.004*"try"')
# (20, '0.280*"order" + 0.009*"took" + 0.008*"menu" + 0.007*"minut" + 0.006*"sauc" + 0.006*"wrong" + 0.006*"arriv" + 0.005*"pick" + 0.005*"serv" + 0.005*"rice" + 0.005*"disappoint" + 0.005*"cook" + 0.005*"dish" + 0.005*"meal" + 0.005*"counter"')
# (14, '0.098*"came" + 0.043*"nice" + 0.035*"definit" + 0.018*"pretti" + 0.016*"delici" + 0.016*"sauc" + 0.015*"dish" + 0.013*"recommend" + 0.010*"flavor" + 0.009*"seat" + 0.009*"meal" + 0.008*"try" + 0.008*"friend" + 0.008*"bit" + 0.008*"wasn"')
# (5, '0.079*"tabl" + 0.055*"ask" + 0.054*"come" + 0.031*"server" + 0.023*"minut" + 0.017*"waiter" + 0.016*"check" + 0.014*"water" + 0.014*"took" + 0.013*"waitress" + 0.012*"seat" + 0.011*"said" + 0.010*"came" + 0.010*"brought" + 0.009*"arriv"')
# (19, '0.395*"place" + 0.011*"try" + 0.008*"look" + 0.007*"recommend" + 0.007*"come" + 0.006*"definit" + 0.006*"peopl" + 0.006*"town" + 0.006*"want" + 0.005*"awesom" + 0.005*"clean" + 0.005*"favorit" + 0.005*"better" + 0.005*"price" + 0.005*"review"')
# (11, '0.317*"servic" + 0.039*"custom" + 0.024*"excel" + 0.020*"friendli" + 0.015*"star" + 0.011*"slow" + 0.010*"attent" + 0.008*"busi" + 0.008*"fast" + 0.008*"bad" + 0.008*"experi" + 0.008*"qualiti" + 0.008*"terribl" + 0.008*"server" + 0.007*"quick"')
# (3, '0.207*"wait" + 0.061*"minut" + 0.032*"long" + 0.028*"seat" + 0.027*"line" + 0.022*"hour" + 0.020*"tabl" + 0.018*"staff" + 0.015*"peopl" + 0.014*"worth" + 0.013*"min" + 0.011*"busi" + 0.010*"arriv" + 0.010*"final" + 0.010*"outsid"')
# (21, '0.433*"great" + 0.022*"staff" + 0.018*"friendli" + 0.016*"atmospher" + 0.014*"recommend" + 0.013*"beer" + 0.013*"awesom" + 0.012*"spot" + 0.009*"select" + 0.009*"definit" + 0.008*"view" + 0.008*"fun" + 0.007*"price" + 0.006*"fantast" + 0.006*"experi"')

# %%
NMF_optimal_model = NMF_model_list[22 - 18]
NMF_topic_list = [
    "Topic 1: Customer Service",
    "Topic 2: Food Taste and Flavor",
    "Topic 3: Menu and Pricing",
    "Topic 4: Food and Service",
    "Topic 5: Location and Parking",
    "Topic 6: Dining Experience",
    "Topic 7: Atmosphere",
    "Topic 8: Service and Table Management",
    "Topic 9: Flavors and Recommendations",
    "Topic 10: Disappointing Experience",
    "Topic 11: Long Wait Times",
    "Topic 12: Wine Tasting Experience",
    "Topic 13: Favorite Place",
    "Topic 14: Re-visit",
    "Topic 15: Atmosphere and Service",
    "Topic 16: Santa Barbara",
    "Topic 17: Dishes and Atmosphere",
    "Topic 18: Room and Hotel Experience",
    "Topic 19: Menu and Dishes",
    "Topic 20: Ordering and Service Issues",
    "Topic 21: Customer Service Quality",
    "Topic 22: Bowls and Flavors"
]

create_heatmap(NMF_optimal_model.top_topics(corpus_removed_labels), NMF_topic_list)

# %% [markdown]
# As we can see, most of the topics in the NMF model are presented in LDA model. One more aspect we observed in NMF model is Topic 14 Re-Visit. FINAL_ASPECT_SET is: Seating, Ambiance,Experience, Waiting Time, Service, Food Taste, Quality, Order, Food Flavor, Gluten-Free Options, Pricing, Vegetarian Options, Nightlife, Events and Setting, Good for Group, Kid friendly, Healthy Options, Location, View, Happy Hour, Cleanliness and Covid Precautions, Re-Visit.

# %%
# Save model result of word distribution to json file
import json
import numpy as np

def convert_float32(obj):
    if isinstance(obj, np.float32):
        return float(obj)
    elif isinstance(obj, list):
        return [convert_float32(item) for item in obj]
    elif isinstance(obj, tuple):
        return tuple(convert_float32(item) for item in obj)
    return obj

data = {
    "LDA": convert_float32(LDA_optimal_model.top_topics(corpus_removed_labels)),
    "NMF": convert_float32(NMF_optimal_model.top_topics(corpus_removed_labels))
}

with open('../data/LDA_NMF_Topics.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)
